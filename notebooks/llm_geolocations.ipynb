# %% [markdown]
# ## Aim:
# How to link the rule-based extracted CI_TYPE-GEO pairs with the respective Ci failure impacts
#
# **Idea**\
# Test using prompt engineering by passing table of CIGEO pairs to GPT-J model.
# Steps:
# * Load model and apply it always on one chunk of the document to extract CI failure impacts
# * Use prompt engineering to extract time and location of the CI failure (origin) the CI impacts (impact location)
# or
# * Pass dataframe of pairs as input to the model
# or
# * Use few shot prompting with example answers
#
# **Finally:**
# * Compaire all approaches of spatial and temporal linking CI failure impacts

# %%
import os
import sys
import subprocess
import importlib

import re
import time
from glob import glob
from pathlib import Path

from io import StringIO

import numpy as np
import pandas as pd
from jinja2 import Environment, FileSystemLoader
from langchain_docling import DoclingLoader
import langdetect

import spacy
from huggingface_hub import login
import transformers
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    AutoModelForSeq2SeqLM,
    BitsAndBytesConfig,
)

import torch

from pdfminer.high_level import extract_text
from docling.backend.pypdfium2_backend import PyPdfiumDocumentBackend
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import (
    PdfPipelineOptions,
    AcceleratorOptions,
    AcceleratorDevice,
)
from docling.pipeline.standard_pdf_pipeline import StandardPdfPipeline
from docling.document_converter import DocumentConverter, FormatOption


sys.path.append("../")
from src.settings import settings as s
import src.document_cleaning as dc
import src.translation_model as tm
# from src.hf_model_access import get_weight_dir


torch.manual_seed(42)

#  automatic linebreaks and multi-line cells.
pd.set_option("display.max_colwidth", None)
pd.set_option("display.colheader_justify", "left")


test_mode = True

torch.cuda.empty_cache() 
print(torch.cuda.memory_reserved() / 1e9)
# Out:
# Running on local machine
# 0.0

# %%
# os.environ["HF_HOME"] = s.HF_HOME_DIR
try: 
    login(token=os.getenv("HUGGINGFACE_TOKEN"))   # notebook_login
except:
    login(token=os.environ.get("HUGGINGFACE_TOKEN"))  # former HF_TOKEN


test_mode = True # for testing purposes, limit number of processed documents
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# ## Set paths and vars

# %%
# set wd to project root
os.chdir("/home/a-buch/Documents/TUB_DWN/_PROJECTS/CI-impacts-information-retrieval")



## set path variables
DOCS_DIR = Path(s.PATH_DATA + "text_sources/")
PARSED_TEXT_DIR = Path(s.PATH_DATA + "parsed_documents/")
LLM_OUTPUTS_DIR = Path(s.PATH_DATA + "llm_outputs/")
NER_PATTERNS_FILEPATH = Path(s.NER_PATTERNS_FILEPATH)

# document cleaning
md_dir = Path(PARSED_TEXT_DIR)
md_dir.mkdir(parents=True, exist_ok=True)

# CI GEO pairs
CI_GEO_FILEPATH = Path("./" + s.PATH_DATA + s.CI_GEO_PAIRS_FILENAME)

## store LLM 1 response and prompt
os.makedirs(s.PATH_LLM_DATA, exist_ok=True)
OUTPUT_LLM1_FILEPATH =  Path(s.PATH_LLM_DATA / s.LLM_DATA_FILENAME)
OUTPUT_PROMPT_FILEPATH = Path(s.PATH_LLM_DATA / f"prompt_{OUTPUT_LLM1_FILEPATH.stem}.txt" )

# %% [markdown]
# ### Set test mode

# %%
if test_mode:
    print("Test mode is ON. Using only a small sample of documents for testing.")

    docs_list_sample = [
        Path(PARSED_TEXT_DIR, "Karakatsani 2023 - Greece economy briefing The economic impact of the recent devastating floods in Greece_cleaned.md"),
        Path(PARSED_TEXT_DIR, "Koks 2022 - Brief communication_cleaned.md"),
        Path(PARSED_TEXT_DIR, "Khazai 2013 - Juni-Hochwasser 2013 in Mitteleuropa - Fokus Deutschland Bericht 2 Auswirkungen und Bewältigung_cleaned.md"),
        Path(PARSED_TEXT_DIR, "European Investment Bank 2025 - Spain_ EIB lends €50 million to Iberdrola to rebuild and climate-proof flood-hit power infrastructure in Valencia_cleaned.md"),
        Path(PARSED_TEXT_DIR, "Wilson 2024 - Flash floods in Spain sweep away cars, disrupt trains and leave several missing _ AP News_cleaned.md"),     
        Path(PARSED_TEXT_DIR, "Wildhagen 2013 - Hochwasser_ Wie die Flut Unternehmen lahmlegt_cleaned.md"),
        Path(PARSED_TEXT_DIR, "Lloyd's List 2024 - Port of Valencia reopens after devastating floods_cleaned.md"),
        Path(PARSED_TEXT_DIR, "Containerlift 2024 - Valencia Port Resumes Operations Following Devastating Flooding in Spain - Containerlift.co.uk - Transport_Lifting_Shipping_cleaned.md"), 
        Path(PARSED_TEXT_DIR, "AEMET 2024 - ESTUDIO SOBRE LA SITUACIÓN DE LLUVIAS INTENSAS_cleaned.md")
    ]


## Test mode
if test_mode:
    search_path = docs_list_sample
    print("Test mode is ON. Using only a small sample of documents for testing.")
else:
    search_path = glob(str(Path(PARSED_TEXT_DIR, "*cleaned.md")))
# Out:
# Test mode is ON. Using only a small sample of documents for testing.
# Test mode is ON. Using only a small sample of documents for testing.

# %% [markdown]
# ###  Load and initialize spaCy language model

# %%
# # spaCy language model for NER and ENTITY LINKING

try: 
    print("Try loading spaCy language model for local machine ...")
    try:
        nlp = spacy.load(s.SPACY_MODEL)
    except (OSError, ValueError):
        print(f"spaCy language model '{s.SPACY_MODEL}' not found. Downloading ...")
        ## loading transformer language model for NER requires additional package
        if (s.SPACY_MODEL.endswith("_trf")):
            # !uv add spacy[transformers]
        # !uv run python -m spacy download {s.SPACY_MODEL}
        nlp = spacy.load(s.SPACY_MODEL)

except (OSError, ValueError):
    try: 
        print(f"spaCy language model '{s.SPACY_MODEL}' not found. Downloading ...")
        subprocess.check_call(["uv", "pip", "install", "spacy-transformers"])
        subprocess.check_call(["uv", "run", "python3", "-m", "spacy", "download", s.SPACY_MODEL])
        nlp = spacy.load(s.SPACY_MODEL)
    except ValueError:
        print("Try downloading directly via python3 -m spacy ... (and not via uv run ...)")
        subprocess.check_call(["python3", "-m", "spacy", "download", s.SPACY_MODEL])


# !uv run python -m spacy download en_core_web_trf
# nlp = spacy.load("en_core_web_trf")
# Out:
# Try loading spaCy language model for local machine ...

# %%
# Initialise spaCy pipeline 
nlp.add_pipe("merge_entities")
nlp.add_pipe("merge_noun_chunks")


# add CI_TYPE patterns to spacy nlp model pipeline
config = {"spans_key": None, "annotate_ents": True, "overwrite": False}
## see for more info: https://spacy.io/usage/rule-based-matching#entityruler
## NOTE EntityRuler is hidden inside .add_pipe()
try:
    ruler = nlp.add_pipe("span_ruler", config=config)
    ruler.from_disk(s.NER_PATTERNS_FILEPATH)
except ValueError:
    print("SpanRuler already exists in pipeline.")
    ruler = nlp.get_pipe("span_ruler")
    ruler.from_disk(s.NER_PATTERNS_FILEPATH)

# %%
## Document cleaning

# %%
# Docling pipeline configs

accelerator_options = AcceleratorOptions(
    num_threads=4, device=AcceleratorDevice.AUTO
)  # use GPU + multi-threading
pipeline_options = PdfPipelineOptions()
pipeline_options.do_ocr = True
pipeline_options.do_table_structure = (
    True  # identify tables as such just not to have them in the TextItems later
)
pipeline_options.accelerator_options = accelerator_options
pipeline_options.force_backend_text = True




# setup converter for PDF and markdown
converted = DocumentConverter(
    allowed_formats=[InputFormat.PDF, InputFormat.MD],
    format_options={
        InputFormat.PDF: FormatOption(
            pipeline_cls=StandardPdfPipeline,
            pipeline_options=pipeline_options,
            backend=PyPdfiumDocumentBackend,
        ),
    },
)

# %%
print( "Number of documents to process:", len(os.listdir(DOCS_DIR)) )


# convert the different layouts of the pdf files into unified markdown format incl. sub/section titles, tables, caption text etc
for pdf_filename in os.listdir(DOCS_DIR):
    if pdf_filename.endswith(".pdf"):

        md_filename = f"{Path(pdf_filename).stem}.md"

        pdf_filepath = os.path.join(DOCS_DIR, Path(pdf_filename))
        md_filepath = os.path.join(PARSED_TEXT_DIR, Path(md_filename))
        cleaned_md_filepath = md_filepath.replace(".md", "_cleaned.md")

        if os.path.exists(md_filepath):
            print(
                f"Markdown file '{md_filepath}' already exists. Skipping conversion and cleaning."
            )
            continue

        start_time = time.time()
        print(f"\nFetching: {pdf_filename}")

        print("Remove reference section")
        pdf_text = extract_text(pdf_filepath)
        pdf_text_no_refs = dc.remove_references(pdf_text)

        print("Removing URLs") # LangExtract tries to open these URLs when they occur in the document text
        pdf_text_no_refs_urls = re.sub(r"http\S+", "", pdf_text_no_refs) 

        # FIXME remove workaround of saving pdf as markdown and reading it again as Docling.Document
        # FIXME with DocLoader
        # loader = DoclingLoader(md_filepath)
        # md_text = loader.load()
        with open(md_filepath, "w", encoding="utf-8") as f:
            f.write(pdf_text_no_refs_urls)
        print("Converting Markdown to text...")
        md_text = converted.convert(md_filepath)

        print("Removing headers and footers\n")
        md_text_cleaned = dc.remove_headers_footers(md_text)

        print(f"Saving parsed and cleaned document as markdown to: {cleaned_md_filepath}")
        md_text_cleaned.document.save_as_markdown(cleaned_md_filepath)

        end_time = time.time() - start_time
        print(f"Parsing and cleaning done. Time elapsed: {end_time:.2f} seconds.")


# visual check of removed items
# TODO make as document_cleaning function: print removed items with largest number of chars first
# ## NOTE. high number of chars == more potentially actual text body

# text_items_removed = sorted(text_items_to_drop_visualization, key=lambda x: -x[0])
# for i in text_items_removed[:50]:
#     print(i) # -->  also subsection titles were removed partly
# Out:
# Number of documents to process: 47
# Markdown file '../data/parsed_documents/UNEP 2013 - Impacts of summer 2003.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Stamataki 2023 - Greece’s record rainfall and flash floods are part of a trend _ PreventionWeb.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Khazai 2013 - Juni-Hochwasser 2013 in Mitteleuropa - Fokus Deutschland Bericht 2 Auswirkungen und Bewältigung.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Koks 2022 - Brief communication.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Yamashita 2008 - Analysis  control  and economic impact assessment of major blackout events.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/AEMET 2024 - ESTUDIO SOBRE LA SITUACIÓN DE LLUVIAS INTENSAS.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Korzilius 2021 Nach der Flut.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Kettle 2020 - Storm Xaver over Europe in December 2013 Overview of energy impacts and North Sea events.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Wildhagen 2013 - Hochwasser_ Wie die Flut Unternehmen lahmlegt.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Kadir 2014 - The Impact of Natural Disasters on Critical Infrastructures - A Domino Effect-based Study.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/European Investment Bank 2025 - Spain_ EIB lends €50 million to Iberdrola to rebuild and climate-proof flood-hit power infrastructure in Valencia.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Luiijf 2010 - Empirical findings on Critical Infrastructure Dependencies in Europe.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/IPCC 2018 - Working Group 2 Cross-chapter case studies.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Stahl 2016 - Impacts of European drought events: insights from an international database of text-based reports.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Koks 2019 - Understanding Business Disruption and Economic Losses Due to Electricity Failures and Flooding.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/McGregor 2007 - The social impacts of heat waves.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Tapsell 2010 - Social vulnerability to natural hazards.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/The Maritime Executive 2024 - A Week After Devastating Floods, Spain’s Valencia Port is Restoring Service.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Fekete 2025 - Cascading impact chains and recovery challenges of the 2024 Valencia catastrophic floods.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Ferlita 2023 - Incendi in Sicilia, ecco cosa accade.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Keller 2014 - Mapping Natural Hazard Impacts on Road Infrastructure—The Extreme Precipitation in Baden-Württemberg.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Containerlift 2024 - Valencia Port Resumes Operations Following Devastating Flooding in Spain - Containerlift.co.uk - Transport_Lifting_Shipping.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Mohr 2022 - A multi-disciplinary analysis of the exceptional flood event of July 2021 in central Europe - Part 1 Event desciption and analysis.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Plag 2014 - Foreword extreme geohazards—a growing threat for a globally interconnected civilization.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Fink 2004 - The 2003 European summer heatwaves and drought - synoptic diagnosis and impacts.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Diakakis 2020 - A systematic assessment of the effects of extreme flash floods on transportation infrastructure and circulation: The example of the 2017 Mandra flood.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Euronews 2024 - Spain floods_ Death toll rises to 205 as nation braces for more rain .md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/ABC 2024 - Traffic jams and flight delays due to heavy rain and lightning storm in Malaga.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Rozendaal 2021 - Infrabel_ Flood damage to railway track worth tens of millions of euros _ SpoorPro - incomplete.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Met office 2014 - Winter-storms-december-2013-to-january-2014.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Skoulding 2023 - Where are the fires in Italy today as temperatures rise to 47.6C on Sicily_ _ The Independent.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/PWC 2015 - Updated estimates on cost of Storm Desmond.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/The Vibes 2022 - Valencia Airport in Madrid briefly shut as lightning hits runway _ World .md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Gilbody Dickerson 2024 - Spain floods_ At least 95 people killed including British man near Malaga _ World News _ Sky News.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Wilson 2024 - Flash floods in Spain sweep away cars, disrupt trains and leave several missing _ AP News.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Korzilius 2021 -  Nach der Flut  Rheinisches Ärzteblatt 10 -  p12–16.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Treanor 2015 - Storm Desmond damage across Cumbria estimated at £500m _ Storm Desmond _The Guardian.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Karakatsani 2023 - Greece economy briefing The economic impact of the recent devastating floods in Greece.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/EFE 2024 - The DANA storm, live_ The death toll rises to 158.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/AFP 2022 - The_Vibes_Valencia Airport in Madrid briefly shut as lightning hits runway _ World _ The Vibes.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Kaur 2025 - Authorities suspect arson in 17 wildfires across Dalmatian coast, Croatia - The Watchers.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Lloyd's List 2024 - Port of Valencia reopens after devastating floods.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/The Guardian 2018 - Freezing weather costs UK economy £1bn a day _ UK weather.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Krausmann 2014 - STREST report on lessons learned from recent catastrophic events.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Brown 2010 - Economy feels chill as UK grinds to a halt _ The Independent.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Artemis 2015 - PERILS finalises Storm Desmond UK flood loss estimate at £604m.md' already exists. Skipping conversion and cleaning.
# Markdown file '../data/parsed_documents/Eurelectric 2006 - Impacts of Severe Storms on Electric Grids.md' already exists. Skipping conversion and cleaning.

# %% [markdown]
# ## LLama

# %% [markdown]
# ###  Prompt engineering

# %%
question_1 = "Which infrastructure failures are mentioned in the text? Categorize the output by the type of infrastructure, the location, and the type of damage."

# %%
env = Environment(loader=FileSystemLoader("./prompt_templates/"))
template = env.get_template("ci_loc_direct_impacts.txt")

# %% [markdown]
# ### Init Llama application function
# * extract CI-GEO pairs (ie. most likely geolocation of each CI_TYPE )
# * pass NER table to prompt for evaluating and improving LLM response
# * Test approach by applying it on three cleaned documents

# %%
# # empty CUDA cache
import gc
import torch

gc.collect()

torch.cuda.empty_cache()
torch.no_grad()
# print(torch.cuda.memory_summary(device=None, abbreviated=False))

# %%
# init class for decoder and tokenizer


class DecoderModel:

    def __init__(self, model_name: str ="meta-llama/Llama-2-7b-chat-hf"):
        
        try: 
            login(token=os.getenv("HUGGINGFACE_TOKEN"))   # notebook_login
        except:
            login(token=os.environ.get("HUGGINGFACE_TOKEN"))  # former HF_TOKEN

        base_dir =  s.HF_HOME_DIR   # use default dir in .cache/
        model_dir = base_dir # / f"models--{model_name.replace("/", "--")}"  # is already .._mirror/hub/
        
        print(model_dir)

        # quantization config
        # Load model with 4-bit quantization if applicable (use 4-bit integer instead of 32b floats) --> reduce the required VRAM for model application
        # see, https://huggingface.co/docs/transformers/quantization
        bnb_config = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_use_double_quant=True,
            bnb_4bit_quant_type="nf4",
            bnb_4bit_compute_dtype=torch.float16,
        )

        self.pipeline, self.tokenizer = self.initialize_model(
            model_name, model_dir, bnb_config
        )
        

    def initialize_model(self, model_name: str, model_dir: str = None, bnb_config=None):
        
        # Model and Tokenizer initialization
        if not os.path.exists(model_dir):
            print("Model directory not found. Downloading model...")
            os.makedirs(model_dir, exist_ok=True)

            device = transformers.infer_device()
            print(f"Using device: {device}")
            model = AutoModelForCausalLM.from_pretrained(
                model_name,
                dtype="auto",
                attn_implementation="flash_attention_2",  # use with 4-bit quantization,
                # --> flash attention enables to use much larger sequence lengths without running into OOM issues
                quantization_config=bnb_config,
                # max_memory={0: "2GB", 1: "10GB"},  # distribute memory across GPUs
            )
            model.save_pretrained(model_dir)
            tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)
            tokenizer.save_pretrained(model_dir)

            print("Downloaded model and tokenizer")

        else:
            print(f"Using locally saved model from {model_dir}")

            model = AutoModelForCausalLM.from_pretrained(
                model_name,
                cache_dir=model_dir,
                local_files_only=True,  # tp_plan="auto" # set tensor parallel model (ie. splits model on multiple GPU)
                dtype="auto",
                attn_implementation="flash_attention_2",  # use with 4-bit quantization,
                # --> flash attention enables to use much larger sequence lengths without running into OOM issues
                quantization_config=bnb_config,
                # tp_plan="auto",  # automatically use a tensor parallelism plan based on predefined configuration of the model (i.e. partition model on both GPUs)
            )
            # print("Tensor parallel plan:", model._tp_plan)

            tokenizer = AutoTokenizer.from_pretrained(
                model_name,
                use_fast=True,
                cache_dir=model_dir,  # use fast Rust-based tokenizer, when possible
            )

        # reduce further memory usage
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        model = model.to(device)
        model.use_checkpointing = True

        torch.cuda.empty_cache()
        torch.no_grad()

        # Pipeline setup for question answering
        pipeline = transformers.pipeline(  # load model locally from wsl .cache\
            "text-generation",
            model=model,
            tokenizer=tokenizer,
            max_new_tokens=1024, # high max token otherwise output is truncated
            device_map="auto",
        )
        return pipeline, tokenizer

    def generate_response(
        self, question: str, context: list, # chunk_id: int
    ):
    
        rendered_prompt = template.render(
            context=context,  # includes also df_ci_geo info
            question=question,
        )

        # print(f"Generating response for chunk_id: {chunk_id} ...")

        sequences = self.pipeline(
            rendered_prompt,  # jinja template
            max_new_tokens=1024, # use default to not truncate the LLM response
            do_sample=True,
            num_beams=1,  # select token based on probability distribution over entire model’s vocabulary
            # top_k=10,
            # top_p=0.5,
            temperature=0.1,
            # num_return_sequences=1,
            eos_token_id=self.tokenizer.eos_token_id,
            return_full_text=False,  # allow bullet point answers
        )
        # Extracting and returning the generated text
        return sequences

# %% [markdown]
# ### Apply Llama on chunks

# %%
## Settings

model_name = "meta-llama/Llama-2-7b-chat-hf"
# test for HPC: "meta-llama/Llama-3.1-8B-Instruct"



## init LLM pipeline
decoder_model = DecoderModel(model_name=model_name)

## init output dataframe
df_responses_all = pd.DataFrame()
sentence_root_list = [] # for visualization of sentence roots and their dependencies
responses_error_list = []

test_mode = True
if test_mode:
    search_path = docs_list_sample
    print("Test mode is ON. Using only a small sample of documents for testing.")
else:
    search_path = glob(str(Path(PARSED_TEXT_DIR, "*cleaned.md")))


## Start CI impact extraction
for i, filename in enumerate(search_path):

    src_language_nonengl = None 

    no_documents = len(search_path)
    filepath = Path(filename)
    filename_stem = filepath.stem



    ## load doc
    loader = DoclingLoader(filepath)  # use chunks from Docling.Loader
    doc = loader.load()


    print(f"\n\n ######## -------- Processing document [{i+1}/{no_documents}]: {filepath.name} -------- ######## \n")

    ## extract authors, publication year and title 
    author, year, title = dc.extract_citation_info(filename_stem)
    citation = f"{author} {year}".replace("  ", " ").strip()
    title = title.replace(" - ", "").replace("_cleaned", "").strip()


    # check language of document based on document title
    # check title rather than chunk_text as later might contain also footer or header info in another languages
    
    src_language_doc = langdetect.detect(str(title).lower())  # lower case improves language detection
    
    if src_language_doc != "en":
        supported_languages = ["fr", "de", "es", "it", "itc", "nl"]
        if src_language_doc not in supported_languages:
            # raise ValueError(f"Unsupported source language: {src_language_doc}")
            print(f"Unsupported source language: {src_language_doc}. Continue with extraction on original text")
            pass
        
        print(f"\n ######## -------- Translating {src_language_doc} text to `en` -------- ######## \n")

        # clean up before applying translator
        gc.collect()
        torch.cuda.empty_cache()  # mainyl after training needed, small effect when LLM applied only for infernece
        torch.no_grad()
        
        # return translated Docling Document
        doc = tm.translate_2_english(src_language_doc, doc)



    print(f"\n ######## -------- Relationship extraction: CI-GEO pairs -------- ######## \n")

    ## Create New entity for transport infrastructure and apply it on any doc

    ## TODO make as pydantic class with fixed attributes
    df_ci_geo = pd.DataFrame(
        columns=[
            "citation_id",
            "chunk_id",
            "ci_entity",
            "geo_entity",
            "case_type",
            "chunk_text",            
        ]
    )

    for chunk_no, chunk in enumerate(doc):


        ## apply customized NLP pipeline -> returns same chunk.text but with CI_entities annotations and without linebreak symbols
        for nlp_chunk in nlp.pipe([chunk.page_content]):

            ci_entities = [ent for ent in nlp_chunk.ents if ent.label_ in ["CI_TYPE"]]

            # check if chunk has no CI_TYPE entities
            if not ci_entities:
                print(f"Chunk [{chunk_no}], CI_TYPE entities found: 0")
                # print(f"\nChunk [{chunk_no}], No. CI_TYPE and FAC entities: {len(ci_entities)}")
                continue
      

            print(f"Chunk [{chunk_no}], CI_TYPE entities found: {len(ci_entities)}")
            

            for ci_ent in ci_entities:
                # print("Ci_ent:", ci_ent.text)

                # Get the root of the sentence 
                sentence_root = ci_ent.sent.root

                if sentence_root.dep_ in ("ROOT", "dobj", "conj"):  # TODO probably enough when set only to ROOT 
                    # sentence_root_list.append(sentence_root.dep_) # for visualization of sentence roots and their dependencies
                    head = ci_ent.root.head
                    # print(f" `{sentence_root, sentence_root.dep_}` is sentence_root, \n `{head}` the direct head of ci entity `{ci_ent}`")

                    subjs = list(sentence_root.lefts) + list(sentence_root.rights)
                    for subj in subjs:
                        for descendant in subj.subtree:

                            # check if descendant is a location entity
                            if descendant.ent_type_ in ("GPE", "LOC"):
                                descendant_loc = descendant
                                print("  ", ci_ent.text, "->", descendant_loc.text)
                                # assert subj is descendant_loc or subj.is_ancestor(descendant_loc)

                                ## Special case handling - one root but multiple ci-geo pairs
                                try:
                                    first_ci_ancestor = [ancestor.text for ancestor in descendant_loc.ancestors if ancestor.ent_type_ in ("CI_TYPE", "FAC")][0]
                                    if ci_ent.text == first_ci_ancestor:
                                        print(
                                            "descendant of location:", descendant_loc.text, descendant_loc.dep_, 
                                            "\nits ancestors:", [ancestor.text for ancestor in descendant_loc.ancestors] # all parents up to root.head
                                        )
                                        print("  ", ci_ent.text, "-->", descendant_loc.text)
                                        
                                        ## write as dict entry incl chunk_id, ci_entity, geo_entity, distance
                                        result_dict = {
                                            "citation_id": citation,
                                            "chunk_id": chunk_no,
                                            "ci_entity": ci_ent.text,
                                            "geo_entity": descendant_loc.text,
                                            "case_type": "special",
                                            "chunk_text": nlp_chunk.text,
                                        }
                                        df_ci_geo = pd.concat(
                                            [df_ci_geo, pd.DataFrame([result_dict])], ignore_index=True
                                        )

                                ## usual case handling
                                except IndexError:
                                    ## write as dict entry incl chunk_id, ci_entity, geo_entity, distance
                                    result_dict = {
                                        "citation_id": citation,
                                        "chunk_id": chunk_no,
                                        "ci_entity": ci_ent.text,
                                        "geo_entity": descendant_loc.text,
                                        "case_type": "usual",
                                        "chunk_text": nlp_chunk.text,
                                    }
                                    df_ci_geo = pd.concat(
                                        [df_ci_geo, pd.DataFrame([result_dict])], ignore_index=True
                                    )

                else:
                    # print("\nNo CI_TYPE or FAC entities found in this chunk.")
                    continue

    ## post-process of DF CI-GEO pairs
    df_ci_geo = df_ci_geo.drop_duplicates(
        subset=["citation_id", "chunk_id", "ci_entity", "geo_entity","case_type", "chunk_text"]
        )# .reset_index(drop=True, inplace=True)


    print(f"\n  #############  -------- Text-2-Data: {filepath.name} -------- #############  \n")

    df_responses = pd.DataFrame(
        columns=[
            "citation_id",
            "chunk_id",
            "infrastructure_type",
            "damage",
            "location",
            "ci_entity",
            "geo_entity",
            "case_type",
            "chunk_text"
        ]
    )

    ## apply decoder on each chunk in document
    ## TODO replace iteration by loading entire document and use recursive chunking from langchain
    for j, chunk in enumerate(doc):

        if df_ci_geo.loc[df_ci_geo["chunk_id"] == j].empty:
            context = [
                {
                    "text": chunk.page_content,
                    "citation": citation,
                    "title": filename_stem, 
                    "ci_locations": None,
                },
            ]
        else:  # TODO disolve if else clause by making it in ci_locations: if df_ci_geo.chunk=j, xx, else None
            context = [
                        {
                            "text": chunk.page_content,
                            "citation": citation,
                            "title": filename_stem, 
                            # TODO check if chunk id is unique per doc and if multiple ci_loc pairs eixist (then just tke first one)
                            "ci_locations": df_ci_geo.loc[df_ci_geo["chunk_id"] == j],
                        },
                    ]

        # apply LLM
        response = decoder_model.generate_response(
            question=question_1, context=context, # chunk_id=j
        )

        ## postprocess response
        resp = response[0]["generated_text"].replace("\n", "")
        try:
            #  remove potential text outside of json object
            resp = (resp.split("]")[0] + "]") 
            # resp = ("[" + resp.split("]")[1])

            # save LLM response for each chunk  in dataframe for each document
            df_resp = pd.read_json(StringIO(resp))
            df_resp["citation_id"] = citation  # add citation info
            df_resp["chunk_id"] = j  # add chunk id as identifier
            df_resp["ci_entity"] = df_ci_geo.loc[df_ci_geo["chunk_id"] == j, "ci_entity"]
            df_resp["geo_entity"] = df_ci_geo.loc[df_ci_geo["chunk_id"] == j, "geo_entity"]
            df_resp["case_type"] = df_ci_geo.loc[df_ci_geo["chunk_id"] == j, "case_type"]
            df_resp["chunk_text"] = df_ci_geo.loc[df_ci_geo["chunk_id"] == j, "chunk_text"]

            df_responses = pd.concat([df_responses, df_resp], ignore_index=True)
        
        except ValueError as e:
            print(f"Cannot add response: {e}, \n   Response (before postprocessing): {response[0]['generated_text'].replace('\n', '')}")
            responses_error_list.append({
                "citation_id": citation,
                "chunk_id": j,
                "response": response[0]['generated_text'].replace('\n', ''),
                "error": str(e)
            })


    df_responses_all = pd.concat([df_responses_all, df_responses], ignore_index=True)


    # clean up after each document
    gc.collect()
    torch.cuda.empty_cache()  # mainly needed after training, small effect when LLM applied only for inference
    torch.no_grad()
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# /home/a-buch/Documents/TUB_DWN/_PROJECTS/CI-impacts-information-retrieval/notebooks/huggingface_mirror/hub
# Using locally saved model from /home/a-buch/Documents/TUB_DWN/_PROJECTS/CI-impacts-information-retrieval/notebooks/huggingface_mirror/hub
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda:0
# Test mode is ON. Using only a small sample of documents for testing.
#
#
#  ######## -------- Processing document [1/9]: Karakatsani 2023 - Greece economy briefing The economic impact of the recent devastating floods in Greece_cleaned.md -------- ########
#
#
#  ######## -------- Relationship extraction: CI-GEO pairs -------- ########
#
# Chunk [0], CI_TYPE entities found: 1
# Chunk [1], CI_TYPE entities found: 0
# Chunk [2], CI_TYPE entities found: 0
# Chunk [3], CI_TYPE entities found: 3
# Chunk [4], CI_TYPE entities found: 0
# Chunk [5], CI_TYPE entities found: 0
# Chunk [6], CI_TYPE entities found: 1
#    the roadshow -> Athens
# descendant of location: Athens pobj
# its ancestors: ['in', 'organized', 'the roadshow', '\n', 'investors', '\n', 'consider']
#    the roadshow --> Athens
# Chunk [7], CI_TYPE entities found: 0
# Chunk [8], CI_TYPE entities found: 0
# Chunk [9], CI_TYPE entities found: 0
#
#   #############  -------- Text-2-Data: Karakatsani 2023 - Greece economy briefing The economic impact of the recent devastating floods in Greece_cleaned.md -------- #############
# Token indices sequence length is longer than the specified maximum sequence length for this model (586 > 512). Running this sequence through the model will result in indexing errors
#  ######## -------- Processing document [2/9]: Koks 2022 - Brief communication_cleaned.md -------- ########
#
#
#  ######## -------- Translating fr text to `en` -------- ########
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# Login with HF TOKEN ...
# /home/a-buch/Documents/TUB_DWN/_PROJECTS/CI-impacts-information-retrieval/notebooks/huggingface_mirror/hub
# Using device: cuda
# Using locally saved model from /home/a-buch/Documents/TUB_DWN/_PROJECTS/CI-impacts-information-retrieval/notebooks/huggingface_mirror/hub
# /home/a-buch/Documents/TUB_DWN/_PROJECTS/CI-impacts-information-retrieval/.venv/lib/python3.12/site-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Detected language for chunk 0: en
# Source and destination language in chunk 0 are identical. No translation needed.
# Detected language for chunk 1: en
# Source and destination language in chunk 1 are identical. No translation needed.
# Detected language for chunk 2: en
# Source and destination language in chunk 2 are identical. No translation needed.
# Detected language for chunk 3: en
# Source and destination language in chunk 3 are identical. No translation needed.
# Detected language for chunk 4: en
# Source and destination language in chunk 4 are identical. No translation needed.
# Detected language for chunk 5: en
# Source and destination language in chunk 5 are identical. No translation needed.
# Detected language for chunk 6: en
# Source and destination language in chunk 6 are identical. No translation needed.
# Detected language for chunk 7: en
# Source and destination language in chunk 7 are identical. No translation needed.
# Detected language for chunk 8: en
# Source and destination language in chunk 8 are identical. No translation needed.
# Detected language for chunk 9: en
# Source and destination language in chunk 9 are identical. No translation needed.
# Detected language for chunk 10: en
# Source and destination language in chunk 10 are identical. No translation needed.
# Detected language for chunk 11: en
# Source and destination language in chunk 11 are identical. No translation needed.
# Detected language for chunk 12: en
# Source and destination language in chunk 12 are identical. No translation needed.
# Detected language for chunk 13: en
# Source and destination language in chunk 13 are identical. No translation needed.
# Detected language for chunk 14: en
# Source and destination language in chunk 14 are identical. No translation needed.
# Detected language for chunk 15: en
# Source and destination language in chunk 15 are identical. No translation needed.
# Detected language for chunk 16: en
# Source and destination language in chunk 16 are identical. No translation needed.
# Detected language for chunk 17: en
# Source and destination language in chunk 17 are identical. No translation needed.
# Detected language for chunk 18: en
# Source and destination language in chunk 18 are identical. No translation needed.
# Detected language for chunk 19: en
# Source and destination language in chunk 19 are identical. No translation needed.
# Detected language for chunk 20: en
# Source and destination language in chunk 20 are identical. No translation needed.
# Detected language for chunk 21: en
# Source and destination language in chunk 21 are identical. No translation needed.
# Detected language for chunk 22: en
# Source and destination language in chunk 22 are identical. No translation needed.
# Detected language for chunk 23: en
# Source and destination language in chunk 23 are identical. No translation needed.
# Detected language for chunk 24: en
# Source and destination language in chunk 24 are identical. No translation needed.
# Detected language for chunk 25: en
# Source and destination language in chunk 25 are identical. No translation needed.
# Detected language for chunk 26: en
# Source and destination language in chunk 26 are identical. No translation needed.
# Detected language for chunk 27: en
# Source and destination language in chunk 27 are identical. No translation needed.
# Detected language for chunk 28: en
# Source and destination language in chunk 28 are identical. No translation needed.
#
#  ######## -------- Relationship extraction: CI-GEO pairs -------- ########
#
# Chunk [0], CI_TYPE entities found: 0
# Chunk [1], CI_TYPE entities found: 2
# Chunk [2], CI_TYPE entities found: 0
# Chunk [3], CI_TYPE entities found: 1
# Chunk [4], CI_TYPE entities found: 1
# Chunk [5], CI_TYPE entities found: 0
# Chunk [6], CI_TYPE entities found: 5
#    road and railway infrastructure -> Germany
#    the 112 bridges -> the Ahr valley
# descendant of location: the Ahr valley pobj
# its ancestors: ['of', 'the ﬂooded 40 km', 'in', 'the 112 bridges', 'Of', 'destroyed']
#    the 112 bridges --> the Ahr valley
#    the 112 bridges -> Rhineland-Palatinate
# descendant of location: Rhineland-Palatinate appos
# its ancestors: ['the Ahr valley', 'of', 'the ﬂooded 40 km', 'in', 'the 112 bridges', 'Of', 'destroyed']
#    the 112 bridges --> Rhineland-Palatinate
#    the 112 bridges -> MDR
#    62 bridges -> the Ahr valley
#    62 bridges -> Rhineland-Palatinate
#    62 bridges -> MDR
# Chunk [7], CI_TYPE entities found: 3
#    The most severely damaged railway line -> Spa
# descendant of location: Spa pobj
# its ancestors: ['of', 'the vil- lages', 'between', 'The most severely damaged railway line', 'reopened']
#    The most severely damaged railway line --> Spa
#    The most severely damaged railway line -> Pepinster
# descendant of location: Pepinster conj
# its ancestors: ['Spa', 'of', 'the vil- lages', 'between', 'The most severely damaged railway line', 'reopened']
#    The most severely damaged railway line --> Pepinster
# Chunk [8], CI_TYPE entities found: 5
#    Several railway sections -> Maastricht
#    Several railway sections -> Liége
#    e.g. the rail- way section -> Maastricht
# descendant of location: Maastricht pobj
# its ancestors: ['between', 'e.g. the rail- way section', 'Several railway sections', 'closed']
#    e.g. the rail- way section --> Maastricht
#    e.g. the rail- way section -> Liége
# descendant of location: Liége conj
# its ancestors: ['Maastricht', 'between', 'e.g. the rail- way section', 'Several railway sections', 'closed']
#    e.g. the rail- way section --> Liége
#    the railway infrastructure -> Maastricht
#    the railway infrastructure -> Liége
#    saturated railway em- bankments -> Maastricht
#    saturated railway em- bankments -> Liége
# Chunk [9], CI_TYPE entities found: 3
#    The gas distribution network -> the Ahr valley
# descendant of location: the Ahr valley pobj
# its ancestors: ['in', 'The gas distribution network', 'damaged']
#    The gas distribution network --> the Ahr valley
# Chunk [10], CI_TYPE entities found: 1
# Chunk [11], CI_TYPE entities found: 5
#    most drink- ing water supply -> Rhineland-Palatinate
#    most drink- ing water supply -> Germany
#    most drink- ing water supply -> Hochwasser Ahr
#    most sewage treatment plants -> Alte- nahr
#    most sewage treatment plants -> Mayschoss
#    most sewage treatment plants -> Sinzig
#    most sewage treatment plants -> Hochwasser Ahr
# Chunk [12], CI_TYPE entities found: 2
#    federal highway -> Heimersheim
# descendant of location: Heimersheim pobj
# its ancestors: ['near', 'federal highway', 'of', '(a) Destruction']
#    federal highway --> Heimersheim
#    the few remaining road and rail bridges -> the Ahr valley
#    the few remaining road and rail bridges -> Altenburg
# Chunk [13], CI_TYPE entities found: 3
#    drinking water supply -> Bad Münstereifel
#    drinking water supply -> North Rhine-Westphalia
#    drinking water supply -> Bad Münstereifel
#    the fresh- water network -> Bad Münstereifel
#    the fresh- water network -> North Rhine-Westphalia
#    the fresh- water network -> Bad Münstereifel
# Chunk [14], CI_TYPE entities found: 6
#    the solid-waste sector -> Rhineland-Palatinate
#    the abandoned highway track -> Belgium
#    the solid waste -> the Netherlands
# Chunk [15], CI_TYPE entities found: 7
#    68 hospitals -> North Rhine-Westphalia
#    the hospital -> Eschweiler
#    the hospital -> Germany
#    The Mutterhaus Ehrang hospital -> Trier
# descendant of location: Trier pobj
# its ancestors: ['in', 'The Mutterhaus Ehrang hospital', 'closed']
#    The Mutterhaus Ehrang hospital --> Trier
#    The Mutterhaus Ehrang hospital -> Germany
# descendant of location: Germany appos
# its ancestors: ['Trier', 'in', 'The Mutterhaus Ehrang hospital', 'closed']
#    The Mutterhaus Ehrang hospital --> Germany
#    the hospital -> Trier
#    the hospital -> Germany
# Chunk [16], CI_TYPE entities found: 4
#    17 schools -> Rhineland-Palatinate
#    17 schools -> Germany
#    emergency educational facilities -> Bad Neuenahr-Ahrweiler
#    various rural clinics -> Belgium
#    one hospital -> the Netherlands
# Chunk [17], CI_TYPE entities found: 2
#    all road segments -> Europe
# descendant of location: Europe pobj
# its ancestors: ['in', 'all road segments', 'for', 'river ﬂood risk', 'assessed']
#    all road segments --> Europe
#    the eight motorway ﬂoods incidents -> Germany
# descendant of location: Germany pobj
# its ancestors: ['in', 'the eight motorway ﬂoods incidents', 'Of', 'three', 'are']
#    the eight motorway ﬂoods incidents --> Germany
# Chunk [18], CI_TYPE entities found: 0
# Chunk [19], CI_TYPE entities found: 4
#    disrupted telecommunication service -> the Netherlands
# Chunk [20], CI_TYPE entities found: 0
# Chunk [21], CI_TYPE entities found: 5
#    almost all historical bridges -> Ahr
#    almost all historical bridges -> Erft
# Chunk [22], CI_TYPE entities found: 1
# Chunk [23], CI_TYPE entities found: 4
#    the electricity network -> Germany
# Chunk [24], CI_TYPE entities found: 0
# Chunk [25], CI_TYPE entities found: 0
# Chunk [26], CI_TYPE entities found: 0
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Chunk [27], CI_TYPE entities found: 0
# Chunk [28], CI_TYPE entities found: 0
#
#   #############  -------- Text-2-Data: Koks 2022 - Brief communication_cleaned.md -------- #############
#
# Cannot add response: Unmatched ''"' when when decoding 'string',
#    Response (before postprocessing): [{    "infrastructure_type": "sewage treatment plants",    "damage": "largely destroyed",    "location": "Alte-nahr",},{    "infrastructure_type": "sewage treatment plants",    "damage": "largely destroyed",    "location": "Mayschoss",},{    "infrastructure_type": "sewage treatment plants",    "damage": "largely destroyed",    "location": "Sinzig",},{    "infrastructure_type": "water supply",    "damage": "disrupted",    "location": "Rhineland-Palatinate",},{    "infrastructure_type": "water supply",    "damage": "contaminated",    "location": "Germany",},{    "infrastructure_type": "groundwater",    "damage": "contaminated",    "location": "flood region",},{    "infrastructure_type": "oil tanks",    "damage": "destroyed",    "location": "residential areas",},{    "infrastructure_type": "industrial plants",    "damage": "contaminated",    "location": "nearby",},{    "infrastructure_type": "wineries",    "damage": "contaminated",    "location": "agriculture",},{    "infrastructure_type": "roads",    "damage": "impassable",    "location": "flood region",},{    "infrastructure_type": "derailed",    "damage": "heavily destroyed",    "location": "railway",},{    "infrastructure_type": "bridges",    "damage": "destroyed",    "location": "flood region",},{    "infrastructure_type": "ports",    "damage": "contaminated",    "location": "coastal areas",},{    "infrastructure_type": "airports",    "damage": "contaminated",    "location": "nearby",},{    "infrastructure_type": "hospitals",    "damage": "disrupted",    "location": "flood region",},{    "infrastructure_type": "schools",    "damage": "disrupted",    "location": "flood region",},{    "infrastructure_type": "residential areas",    "damage": "heavily destroyed",    "location": "flood region",},{    "infrastructure_type": "public buildings",    "damage": "heavily destroyed",    "location": "flod region",},{    "infrastructure_type": "utility services",    "damage": "disrupted",    "location": "flod region",},{    "infrastructure_type": "communication",    "damage": "disrupted",    "location": "flod region",},{    "infrastructure_type": "energy",    "damage": "disrupted",    "location": "flod region",},{    "infrastructure_type": "transportation",    "damage": "disrupted",    "location": "flod region",},{    "infrastructure_type": "public transportation",    "damage": "disrupted",    "location": "flod region",},{    "infrastructure_type": "healthcare",    "damage": "disrupted",    "location": "flod region",},{    "infrastructure_type": "emergency services",    "damage": "disrupted",    "location": "flod region",},{    "infrastructure_type": "government buildings",    "damage": "heavily destroyed",    "location": "flod region",},{    "infrastructure_type": "municip
# Token indices sequence length is longer than the specified maximum sequence length for this model (585 > 512). Running this sequence through the model will result in indexing errors
#  ######## -------- Processing document [3/9]: Khazai 2013 - Juni-Hochwasser 2013 in Mitteleuropa - Fokus Deutschland Bericht 2 Auswirkungen und Bewältigung_cleaned.md -------- ########
#
#
#  ######## -------- Translating de text to `en` -------- ########
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# Login with HF TOKEN ...
# /home/a-buch/Documents/TUB_DWN/_PROJECTS/CI-impacts-information-retrieval/notebooks/huggingface_mirror/hub
# Using device: cuda
# Using locally saved model from /home/a-buch/Documents/TUB_DWN/_PROJECTS/CI-impacts-information-retrieval/notebooks/huggingface_mirror/hub
# /home/a-buch/Documents/TUB_DWN/_PROJECTS/CI-impacts-information-retrieval/.venv/lib/python3.12/site-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Detected language for chunk 0: de
# Source text:  Juni-Hochwasser 2013 in Mitteleuropa - Fokus Deutschland Bericht 2: Auswirkungen und Bewältigung1
# (Der Bericht berücksichtigt die Entwicklung bis zum 11. Juni 2013, 16:00 Uhr)
# Autoren: Bijan Khazai, Tina Bessel, Stella Möhrle, André Dittrich, Kai Schröter, Bernhard Mühr, Florian Elmer, Tina Kunz-Plapp, Werner Trieselmann, Michael Kunz
# Deichbruch bei Fischbeck (Foto, 10.Juni 2013) Landkreis Stendal, im Norden Sachsen-Anhalts (Foto: Berns-Volker Brahms / Volksstimme)2
# 1 Der Bericht wurde am 13.06.2013 publiziert. Abbildung 1, Seite 6; Tabelle 13 und Abbildung 12, Seite 20 wurden am 19.06.2013 überarbeitet.
# Translated text:  June 2013 in Central Europe - Focus Germany Report 2: Impacts and coping1 (The report takes into account the development until 11 June 2013, 4:00 p.m.) Authors: Bijan Khazai, Tina Bessel, Stella Möhrle, André Dittrich, Kai Schröter, Bernhard Mühr, Florian Elmer, Tina Kunz-Plapp, Werner Trieselmann, Michael Kunz Deichbruch bei Fischbeck (Photo, 10 June 2013) Stendal district, in the north of Saxony-Anhalt (Photo: Berns-Volker Brahms / Volksstimme)2 1 The report was published on 13.06.2013. Figure 1, page 6; Table 13 and Figure 12, page 20 were revised on 19.06.2013.
# Detected language for chunk 1: de
# Source text:  2 Nach einem Deichbruch bei Fischbeck (Foto) im Norden Sachsen-Anhalts läuft seit der Nacht zum Montag (10.6.2013) Elbwasser in den Elbe- Havel-Winkel; 6000 Menschen in mehreren Orten wurden bis 12.06. bereits evakuiert, 40.000 insgesamt in Sachsen-Anhalt. Der gebrochene Deich kann erst bei abnehmendem Pegel geschlossen werden, der hier in der Spitze mit 8,20 Metern um 52 Zentimeter über dem Rekordpegel von 2002 lag. Mit freundlicher Genehmigung der Chefredaktion „Volksstimme“ (Magdeburg / Stendal).
# Translated text:  2 After a dike break near Fischbeck (photo) in the north of Saxony-Anhalt since the night of Monday (10 June 2013) Elbe water has been running in the Elbe Havel angle; 6000 people in several places have already been evacuated until 12 June, 40,000 in total in Saxony-Anhalt. The broken dike can only be closed when the level is decreasing, which was 52 centimetres above the record level of 2002 in the top with 8.20 meters. Courtesy of the chief editorial "Volksstimme" (Magdeburg / Stendal).
# Detected language for chunk 2: de
# Source text:  Zusammenfassung......................................................................................................................... - 4 -
# Kurzüberblick zum Hochwasser ............................................................................................ - 5 -
# Translated text:  Summary................................................................................................................................................... - 4 - Short overview of floods................................................................................................... - 5 -
# Detected language for chunk 3: de
# Source text:  Auswirkungen und Schäden ................................................................................................. - 6 -
# Allgemeine Auswirkungen ............................................................................................... - 6 -
# Translated text:  Impacts and damage .................................................................................................................................................................... 6 - General effects .................................................................................................................... 6 -
# Detected language for chunk 4: de
# Source text:  Auswirkungen auf die Verkehrsinfrastruktur ..................................................................... - 7 -
# Analyse von Twitter-Meldungen zu Auswirkungen des Hochwassers ..................................12
# Translated text:  Impact on transport infrastructure ..................................................................................................... 7 - Analysis of Twitter messages on flood impacts ...................................................12
# Detected language for chunk 5: de
# Source text:  Bewältigung ............................................................................................................................14
# Evakuierungen ...................................................................................................................14
# Translated text:  Management ....................................................................................................................................................................14 Evacuations ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
# Detected language for chunk 6: de
# Source text:  Resilienz in den betroffenen Gebieten: Indikatoren-basierte Analyse ..................................15
# Analyse der Auswirkungen des Hochwassers.....................................................................18
# 3.4  Gegenüberstellung von Resilienzpotential und Evakuierungen ...........................................21
# Translated text:  Resilience in the affected areas: Indicator-based analysis ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................... ...
# Detected language for chunk 7: de
# Source text:  Literatur und Quellen ...............................................................................................................22
# Basisinformationen Hydrometeorologie (siehe Report 1, Report 1 UPDATE)
# Deutschland (Sachsen-Anhalt, Sachsen, Thüringen, Bayern) Österreich, Tschechische Republik; Einzugsgebiete der Donau (mit Regen, Lech, Inn) und Elbe (mit Saale, Mulde)
# Translated text:  Literature and sources .............................................................................................................................................22 Basic information Hydrometeorology (see Report 1, Report 1 UPDATE) Germany (Saxony-Anhalt, Saxony, Thuringia, Bavaria) Austria, Czech Republic; catchment areas of the Danube (with rain, Lech, Inn) and Elbe (with Saale, Mulde)
# Detected language for chunk 8: de
# Source text:  Größte räumliche Ausdehnung aller Hochwasserereignisse seit 1950 (&gt;37% des dt. Gewässernetzes mind. 5-jährlichem Hochwasser betroffen) An vielen Pegeln im Donau- und Elbeeinzugsgebiet neue Rekordwerte (Wasserstand, Abfluss)
# Hochwassertyp: Verbreitet Flusshochwasser mit Ausuferungen und Gefahr des Deichversagens mit flächiger Überschwemmung des Hinterlandes
# Schneedecke im alpinen Hochgebirge bis in den Mai. Sehr feuchter Mai, deshalb weitverbreitete Übersättigung des Bodens (größtes Ausmaß seit 50 Jahren), stark reduzierte Wasseraufnahmekapazität des Bodens.
# Translated text:  Figure 1: Comparison of events in 1954 and 2002 with the current June 2013 event: Maximum annuality (high water probability as a return interval) of rivers leading to floods
# Detected language for chunk 25: de
# ...
# Translated text:  As soon as better information on the flood area is available, the exposed elements can also be taken into account and used for normalization. In addition, the evacuation measures also depend on dike failure, which cannot be taken into account in the analyses at present. Nevertheless, as a preliminary overview of the resilience index and the number of evacuations of affected people can be compared (see Figure 14). Even if the pattern is not quite clear, the districts with a higher resilience index seem to have to take less evacuation measures. As soon as more information on flood areas and damage becomes known in the next few days, the
# Detected language for chunk 75: de
# Source text:  räumliche Verteilung der Resilienz gemäß den Indikatoren validiert werden. Die Betrachtung von Evakuierungsmustern (z.B. Anzahl der von Evakuierung Betroffenen, Anzahl der in Notunterkünften untergebrachten Personen), Grad der Vorbereitung und Ef- fektivität der Krisenbewältigung beim Hochwasser 2013 können helfen, durch weitere Forschung Faktoren und Trends der (Hochwasser-)Resilienz in Deutschland zu untersuchen zu verstehen und letztlich die Resilienz zu verbessern.
# Abbildung 14: Gegenüberstellung von Personen in Evakuierungsmaßnahmen und Resilienzindex für Landkreise mit aufgetrete- nen Jährlichkeiten von Tn &gt; 100 Jahre an den Hochwasserführenden Flüssen.
# Translated text:  The assessment of evacuation patterns (e.g. the number of persons affected by evacuation, the number of persons housed in emergency shelters), the degree of preparation and ef-fectivity of crisis management during floods in 2013 can help to understand factors and trends of (high-water) resilience in Germany through further research and ultimately to improve resilience. Figure 14: Comparison of persons in evacuation measures and resilience index for districts with occurred annuality of Tn &gt; 100 years at the flood-bearing rivers.
# Detected language for chunk 76: en
# Source and destination language in chunk 76 are identical. No translation needed.
# Detected language for chunk 77: de
# Source text:  Diesen Bericht, weitere Berichte und Informationen zum Juni-Hochwasser 2013 sowie Updates finden Sie online auf www.cedim.de.
# Zur Erklärung von Fachbegriffen stellt CEDIM das Glossar “Begriffe und Definitionen aus den Risikowissenschaften” www.cedim.de/download/glossar-gesamt-20050624.pdf zur Verfügung.
# Translated text:  This report, further reports and information on the June flood 2013 as well as updates can be found online at www.cedim.de. For the explanation of technical terms, CEDIM provides the glossary , terms and definitions from the risk sciences, www.cedim.de/download/glossary-total-20050624.pdf.
#
#  ######## -------- Relationship extraction: CI-GEO pairs -------- ########
#
# Chunk [0], CI_TYPE entities found: 0
# Chunk [1], CI_TYPE entities found: 2
#    a dike break -> Saxony-Anhalt
#    a dike break -> Saxony-Anhalt
# Chunk [2], CI_TYPE entities found: 0
# Chunk [3], CI_TYPE entities found: 0
# Chunk [4], CI_TYPE entities found: 0
# Chunk [5], CI_TYPE entities found: 0
# Chunk [6], CI_TYPE entities found: 0
# Chunk [7], CI_TYPE entities found: 0
# Chunk [8], CI_TYPE entities found: 1
# Chunk [9], CI_TYPE entities found: 0
# Chunk [10], CI_TYPE entities found: 2
# Chunk [11], CI_TYPE entities found: 0
# Chunk [12], CI_TYPE entities found: 0
# Chunk [13], CI_TYPE entities found: 1
# Chunk [14], CI_TYPE entities found: 0
# Chunk [15], CI_TYPE entities found: 1
# Chunk [16], CI_TYPE entities found: 0
# Chunk [17], CI_TYPE entities found: 0
# Chunk [18], CI_TYPE entities found: 0
# Chunk [19], CI_TYPE entities found: 0
# Chunk [20], CI_TYPE entities found: 0
# Chunk [21], CI_TYPE entities found: 0
# Chunk [22], CI_TYPE entities found: 0
# Chunk [23], CI_TYPE entities found: 1
#    the overall water network -> Würzburg
#    the overall water network -> Südbayern
#    the overall water network -> Augsburg
# Chunk [24], CI_TYPE entities found: 0
# Chunk [25], CI_TYPE entities found: 0
# Chunk [26], CI_TYPE entities found: 1
#    Numerous dike breaks -> Bavaria
# descendant of location: Bavaria pobj
# its ancestors: ['in', 'example', 'for', 'Numerous dike breaks', 'resulted']
#    Numerous dike breaks --> Bavaria
#    Numerous dike breaks -> the Elbe
# descendant of location: the Elbe pobj
# its ancestors: ['along', 'in', 'example', 'for', 'Numerous dike breaks', 'resulted']
#    Numerous dike breaks --> the Elbe
# Chunk [27], CI_TYPE entities found: 2
# Chunk [28], CI_TYPE entities found: 0
# Chunk [29], CI_TYPE entities found: 0
# Chunk [30], CI_TYPE entities found: 0
# Chunk [31], CI_TYPE entities found: 0
# Chunk [32], CI_TYPE entities found: 0
# Chunk [33], CI_TYPE entities found: 0
# Chunk [34], CI_TYPE entities found: 0
# Chunk [35], CI_TYPE entities found: 2
# Chunk [36], CI_TYPE entities found: 3
# Chunk [37], CI_TYPE entities found: 0
# Chunk [38], CI_TYPE entities found: 2
# Chunk [39], CI_TYPE entities found: 2
#    the federal roads -> Traunstein
#    the federal roads -> the Erzgebirgskreis
# Chunk [40], CI_TYPE entities found: 0
# Chunk [41], CI_TYPE entities found: 0
# Chunk [42], CI_TYPE entities found: 1
# Chunk [43], CI_TYPE entities found: 0
# Chunk [44], CI_TYPE entities found: 1
# Chunk [45], CI_TYPE entities found: 1
# Chunk [46], CI_TYPE entities found: 0
# Chunk [47], CI_TYPE entities found: 0
# Chunk [48], CI_TYPE entities found: 0
# Chunk [49], CI_TYPE entities found: 0
# Chunk [50], CI_TYPE entities found: 0
# Chunk [51], CI_TYPE entities found: 1
# Chunk [52], CI_TYPE entities found: 1
# Chunk [53], CI_TYPE entities found: 0
# Chunk [54], CI_TYPE entities found: 1
#    a hospital -> Wittenberg
#    a hospital -> Salzlandkreis
#    a hospital -> Jerichow
#    a hospital -> Anhalt-Bitterfeld
# Chunk [55], CI_TYPE entities found: 2
# Chunk [56], CI_TYPE entities found: 1
# Chunk [57], CI_TYPE entities found: 0
# Chunk [58], CI_TYPE entities found: 0
# Chunk [59], CI_TYPE entities found: 0
# Chunk [60], CI_TYPE entities found: 0
# Chunk [61], CI_TYPE entities found: 0
# Chunk [62], CI_TYPE entities found: 1
# Chunk [63], CI_TYPE entities found: 0
# Chunk [64], CI_TYPE entities found: 0
# Chunk [65], CI_TYPE entities found: 0
# Chunk [66], CI_TYPE entities found: 0
# Chunk [67], CI_TYPE entities found: 0
# Chunk [68], CI_TYPE entities found: 1
# Chunk [69], CI_TYPE entities found: 0
# Chunk [70], CI_TYPE entities found: 0
# Chunk [71], CI_TYPE entities found: 2
#    German highways -> Heidelberg
# descendant of location: Heidelberg appos
# its ancestors: ['German highways', 'on', 'Total index', 'Table', 'Figure']
#    German highways --> Heidelberg
#    German highways -> Saxon
# descendant of location: Saxon appos
# its ancestors: ['Heidelberg', 'German highways', 'on', 'Total index', 'Table', 'Figure']
#    German highways --> Saxon
#    German highways -> Switzerland
# descendant of location: Switzerland appos
# its ancestors: ['Heidelberg', 'German highways', 'on', 'Total index', 'Table', 'Figure']
#    German highways --> Switzerland
# Chunk [72], CI_TYPE entities found: 2
# Chunk [73], CI_TYPE entities found: 0
# Chunk [74], CI_TYPE entities found: 0
# Chunk [75], CI_TYPE entities found: 0
# Chunk [76], CI_TYPE entities found: 0
# Chunk [77], CI_TYPE entities found: 0
#
#   #############  -------- Text-2-Data: Khazai 2013 - Juni-Hochwasser 2013 in Mitteleuropa - Fokus Deutschland Bericht 2 Auswirkungen und Bewältigung_cleaned.md -------- #############
#
# Cannot add response: Expected object or value,
#    Response (before postprocessing):  Here are the infrastructure failures mentioned in the text, categorized by type of infrastructure, location, and type of damage:[{    "infrastructure_type": "Dike",    "damage": "severely damaged",    "location": "Saxony-Anhalt",},{    "infrastructure_type": "Road",    "damage": "blocked",    "location": "Saxony-Anhalt",},{    "infrastructure_type": "Waterway",    "damage": "disrupted",    "location": "Elbe Havel angle",},{    "infrastructure_type": "Dam",    "damage": "failed",    "location": "Fischbeck",},{    "infrastructure_type": "Road",    "damage": "outages",    "location": "Saxony-Anhalt",},{    "infrastructure_type": "Waterway",    "damage": "contaminated",    "location": "Elbe Havel angle",},{    "infrastructure_type": "Dike",    "damage": "largely destroyed",    "location": "Saxony-Anhalt",},{    "infrastructure_type": "Road",    "damage": "heavily destroyed",    "location": "Saxony-Anhalt",},{    "infrastructure_type": "Waterway",    "damage": "partly closed",    "location": "Elbe Havel angle",},{    "infrastructure_type": "Dam",    "damage": "derailed",    "location": "Fischbeck",},{    "infrastructure_type": "Road",    "damage": "impassable",    "location": "Saxony-Anhalt",},{    "infrastructure_type": "Waterway",    "damage": "water or debris",    "location": "Elbe Havel angle",},{    "infrastructure_type": "Dike",    "damage": "water or debris on road",    "location": "Saxony-Anhalt",},{    "infrastructure_type": "Dam",    "damage": "indirectly affected",    "location": "Fischbeck",},{    "infrastructure_type": "Road",    "damage": "closures",    "location": "Saxony-Anhalt",},{    "infrastructure_type": "Waterway",    "damage": "disrupted",    "location": "Elbe Havel angle",},{    "infrastructure_type": "Dam",    "damage": "failure",    "location": "Fischbeck",},{    "infrastructure_type": "Road",    "damage": "outages",    "location": "Saxony-Anhalt",},{    "infrastructure_type": "Waterway",    "damage": "contaminated",    "location": "Elbe Havel angle",},{    "infrastructure_type": "Dike",    "damage": "largely destroyed",    "location": "Saxony-Anhalt",},{    "infrastructure_type": "Road",    "damage": "heavily destroyed",    "location": "Saxony-Anhalt",},{    "infrastructure_type": "Waterway",    "damage": "partly closed",    "location": "Elbe Havel angle",},{    "infrastructure_type": "Dam",    "damage": "derailed",    "location": "Fischbeck",},{    "infrastructure_type": "Road",    "damage": "impassable",    "location": "Saxony-Anhalt",},{    "infrastructure_type": "Waterway",    "damage": "
# Cannot add response: Expected object or value,
#    Response (before postprocessing): [{    "infrastructure_type": "roads",    "damage": "severely damaged",    "location": "Mexico",},{    "infrastructure_type": "bridges",    "damage": "heavily destroyed",    "location": "Thailand",},{    "infrastructure_type": "ports",    "damage": "largely destroyed",    "location": "India",},{    "infrastructure_type": "airports",    "damage": "partially closed",    "location": "United States",},{    "infrastructure_type": "railways",    "damage": "disrupted",    "location": "Brazil",},{    "infrastructure_type": "water_supply",    "damage": "contaminated",    "location": "South Africa",},{    "infrastructure_type": "electricity",    "damage": "outages",    "location": "Canada",},{    "infrastructure_type": "public_buildings",    "damage": "heavily destroyed",    "location": "Australia",},{    "infrastructure_type": "healthcare",    "damage": "severely damaged",    "location": "Russia",},{    "infrastructure_type": "education",    "damage": "partially closed",    "location": "Japan",},{    "infrastructure_type": "communication",    "damage": "disrupted",    "location": "Germany",},{    "infrastructure_type": "tourism",    "damage": "largely destroyed",    "location": "France",},{    "infrastructure_type": "agriculture",    "damage": "heavily destroyed",    "location": "China",},{    "infrastructure_type": "energy",    "damage": "outages",    "location": "Indonesia",},{    "infrastructure_type": "ports",    "damage": "severely damaged",    "location": "United Kingdom",},{    "infrastructure_type": "railways",    "damage": "disrupted",    "location": "Italy",},{    "infrastructure_type": "water_supply",    "damage": "contaminated",    "location": "Spain",},{    "infrastructure_type": "public_buildings",    "damage": "heavily destroyed",    "location": "Poland",},{    "infrastructure_type": "healthcare",    "damage": "partially closed",    "location": "Norway",},{    "infrastructure_type": "education",    "damage": "disrupted",    "location": "Sweden",},{    "infrastructure_type": "communication",    "damage": "heavily destroyed",    "location": "Finland",},{    "infrastructure_type": "tourism",    "damage": "largely destroyed",    "location": "Denmark",},{    "infrastructure_type": "agriculture",    "damage": "heavily destroyed",    "location": "Iceland",},{    "infrastructure_type": "energy",    "damage": "outages",    "location": "Portugal",},{    "infrastructure_type": "ports",    "damage": "heavily damaged",    "location": "Ireland",},{    "infrastructure_type": "railways",    "damage": "disrupted",    "location": "Belgium",},{    "infrastructure_type": "water_supply",    "damage": "contaminated",
# Cannot add response: Expected object or value,
#    Response (before postprocessing): [{    "infrastructure_type": "River",    "damage": "severely damaged",    "location": "Weser",},{    "infrastructure_type": "River",    "damage": "heavily destroyed",    "location": "Rhine",},{    "infrastructure_type": "Road",    "damage": "blocked",    "location": "Tauber Main",},{    "infrastructure_type": "Railway",    "damage": "derailed",    "location": "Neckar",},{    "infrastructure_type": "Catchment area",    "damage": "contaminated",    "location": "Weser",},{    "infrastructure_type": "Catchment area",    "damage": "water or debris on road",    "location": "Rhine",},{    "infrastructure_type": "Dam",    "damage": "dam failure",    "location": "Rhine",},{    "infrastructure_type": "Closure",    "damage": "outages",    "location": "Central and Lower Rhine",},{    "infrastructure_type": "Geographical feature",    "damage": "impassable",    "location": "Weser",},{    "infrastructure_type": "Geographical feature",    "damage": "derailed",    "location": "Neckar",},{    "infrastructure_type": "Geographical feature",    "damage": "disrupted",    "location": "Tauber Main",},{    "infrastructure_type": "Geographical feature",    "damage": "heavily destroyed",    "location": "Rhine",},{    "infrastructure_type": "Geographical feature",    "damage": "largely destroyed",    "location": "Weser",},{    "infrastructure_type": "Geographical feature",    "damage": "partly closed",    "location": "Central and Lower Rhine",},{    "infrastructure_type": "Geographical feature",    "damage": "severely damaged",    "location": "Rhine",},{    "infrastructure_type": "Geographical feature",    "damage": "water or debris",    "location": "Weser",},{    "infrastructure_type": "Geographical feature",    "damage": "water or debris on road",    "location": "Rhine",},{    "infrastructure_type": "Geographical feature",    "damage": "heavily affected",    "location": "Tauber Main",},{    "infrastructure_type": "Geographical feature",    "damage": "largely affected",    "location": "Neckar",},{    "infrastructure_type": "Geographical feature",    "damage": "indirectly affected",    "location": "Weser",},{    "infrastructure_type": "Geographical feature",    "damage": "outages",    "location": "Central and Lower Rhine",},{    "infrastructure_type": "Geographical feature",    "damage": "contaminated",    "location": "Rhine",},{    "infrastructure_type": "Geographical feature",    "damage": "water or debris",    "location": "Weser",},{    "infrastructure_type": "Geographical feature",    "damage": "water or debris on road",    "location": "Rhine",},{    "infrastructure_type": "Geographical feature",    "damage": "heavily destroyed",    "location": "Tauber Main",},{    "infrastructure_type": "Geographical feature",

# %%
print("Chunk with erroneous responses:", responses_error_list.__len__())
df_responses_error = pd.DataFrame(responses_error_list)
df_responses_error.tail(3)
# Out:
# Chunk with erroneous responses: 147
#     citation_id  chunk_id  \
# 144  AEMET 2024  151
# 145  AEMET 2024  152
# 146  AEMET 2024  153
#
#     response                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         \
# 144                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Here are the infrastructure failures mentioned in the text, categorized by type of infrastructure, location, and type of damage:[{"infrastructure_type": "Roads","damage": "heavily damaged, largely destroyed, impassable due to water/debris/risk aquaplaning","location": "Midwest"},{"infrastructure_type": "Railways","damage": "disrupted, blocked (through trees, roofs)","location": "Northern Hemisphere"},{"infrastructure_type": "Electricity","damage": "outages, severely damaged","location": "Midwest"},{"infrastructure_type": "Water","damage": "contaminated, largely destroyed","location": "Eastern Spain"},{"infrastructure_type": "Bridges","damage": "heavily damaged, destroyed","location": "Midwest"},{"infrastructure_type": "Airports","damage": "severely damaged, largely destroyed","location": "Northern Hemisphere"},{"infrastructure_type": "Hospitals","damage": "heavily damaged, largely destroyed","location": "Midwest"},{"infrastructure_type": "Schools","damage": "heavily damaged, largely destroyed","location": "Midwest"},{"infrastructure_type": "Government buildings","damage": "heavily damaged, largely destroyed","location": "Midwest"},{"infrastructure_type": "Residential areas","damage": "heavily damaged, largely destroyed","location": "Midwest"}]Note: The "location" field is based on the information provided in the context, and may not be accurate or complete for all cases.
# 145                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Here are the infrastructure failures mentioned in the context, categorized by type, location, and damage:[{    "infrastructure_type": "Roads",    "damage": "Largely destroyed, heavily damaged, and impassable due to water/debris/risk aquaplaning on road.",    "location": "Jávea"},{    "infrastructure_type": "Railways",    "damage": "Disrupted and derailed due to flooding.",    "location": "La Safor"},{    "infrastructure_type": "Electricity",    "damage": "Severely damaged and largely destroyed due to flooding.",    "location": "Jávea"},{    "infrastructure_type": "Water supply",    "damage": "Contaminated and severely damaged due to flooding.",    "location": "La Safor"},{    "infrastructure_type": "Buildings",    "damage": "Largely destroyed, heavily damaged, and affected by debris due to flooding.",    "location": "Jávea"},{    "infrastructure_type": "Airports",    "damage": "Disrupted and affected by debris due to flooding.",    "location": "La Safor"}]Note: The "location" field is based on the CI locations provided in the context.
# 146   Here are the infrastructure failures mentioned in the context, categorized by type, location, and damage:[{"infrastructure_type": "Power grid","damage": "Largely destroyed in Western North America due to extreme precipitation from cut-off lows under a warming climate.","location": "Western North America"},{"infrastructure_type": "Roads","damage": "Severely damaged in Western North America due to water and debris from extreme precipitation, making some roads impassable.","location": "Western North America"},{"infrastructure_type": "Railways","damage": "Disrupted in Western North America due to flooding and landslides caused by extreme precipitation.","location": "Western North America"},{"infrastructure_type": "Airports","damage": "Little to no damage reported in Western North America due to extreme precipitation.","location": "Western North America"},{"infrastructure_type": "Water treatment plants","damage": "Contaminated in Western North America due to flooding caused by extreme precipitation, leading to water quality issues.","location": "Western North America"},{"infrastructure_type": "Dams","damage": "Failed in Western North America due to extreme precipitation, causing flooding downstream.","location": "Western North America"},{"infrastructure_type": "Bridges","damage": "Severely damaged in Western North America due to flooding and landslides caused by extreme precipitation.","location": "Western North America"},{"infrastructure_type": "Tunnels","damage": "Disrupted in Western North America due to flooding and landslides caused by extreme precipitation.","location": "Western North America"},{"infrastructure_type": "Ports","damage": "Little to no damage reported in Western North America due to extreme precipitation.","location": "Western North America"}]Note: The "location" field is based on the CI locations mentioned in the context.
#
#     error
# 144  Expected object or value
# 145  Expected object or value
# 146  Expected object or value

# %% [markdown]
# #### response

# %%
safety_df = df_responses_all.copy()

# save LLM 1 output to disk along with prompt text
if not os.path.isfile(OUTPUT_LLM1_FILEPATH):

    print(f"Saving prompt, LLM response {OUTPUT_LLM1_FILEPATH.stem}, and erroneous LLM responses [.txt, .csv] to {OUTPUT_LLM1_FILEPATH.parent} ...")
    
    with open(OUTPUT_PROMPT_FILEPATH, "w") as f:
        f.write(template.render(context=context, question=question_1))
    
    df_responses_all.to_csv(OUTPUT_LLM1_FILEPATH, index=False)
    df_responses_error.to_csv(Path(OUTPUT_LLM1_FILEPATH.parent, f"errors_{OUTPUT_LLM1_FILEPATH.stem}.csv"), index=False)

else:
    print(f"Output file {Path(OUTPUT_LLM1_FILEPATH).stem} already exists. Skip saving to avoid overwriting ...")



    # # check if file exists already
    # if os.path.exists(OUTPUT_LMM1_FILEPATH):
    #     print(f"File {OUTPUT_LMM1_FILEPATH.name} already exists. Not saving to disk.")
    #     pass
    # else:
    #     print(f"Saving LLM 1 output to {OUTPUT_LMM1_FILEPATH}")
    #     df_responses_all.to_csv(OUTPUT_LMM1_FILEPATH, index=False)
# Out:
# Saving prompt, LLM response llm1_2026-02-11, and erroneous LLM responses [.txt, .csv] to ../data/llm_outputs ...

# %% [markdown]
# ## Evaluation - only manually

# %% [markdown]
# ### Manual comparison CI_location_table vs LLm response

# %% [markdown]
# #### chunk 5
# In Germany, road and railway infrastructure was severely damaged as documented exemplarily in Fig. 1. Cost estimates reach up to EURO 2 billion Euro (MDR, 2021). More than 130 km of motorways were closed directly after the event, of which 50 km were still closed two months later, with an estimated repair cost of EUR 100 million (Hauser, 2021). Of the 112 bridges in the ﬂooded 40 km of the Ahr valley (Rhineland-Palatinate), 62 bridges were destroyed, 13 were severely damaged and only 35 were in operation a month after the ﬂood event (MDR, 2021). Over 74 km of roads, paths and bridges in the Ahr valley have been (critically) damaged. In some cases, repairs are expected to take months to years (Zeit Online, 2021). For example, major freeway sections, including parts of the A1 motorway, were closed until early 2022 (24Rhein, 2022). In addition, about 50 000 cars were damaged, causing insurance claims of some EUR 450 million (ADAC, 2021). The German railway provider Deutsche Bahn expects asset damages of around EUR 1.3 billion. Among other things, 180 level crossings, almost 40 signal'

# %%
doc[5].page_content

# %%
df_ci_geo[df_ci_geo["chunk_id"] == 5]

# %%
df_responses[df_responses["chunk_id"] == 5]

# %%
print(
    f"CI_TYPE \n LLM responses:\n {df_responses.infrastructure_type.unique()}, \n\n NER pairs:\n {df_ci_geo.ci_entity.unique()}"
)

# %%
print(
    f"LOCATION:\n LLm responses:\n {df_responses.location.unique()}, \n\n NER pairs:\n {df_ci_geo.geo_entity.unique()}"
)

# %% [markdown]
# ### chunk 13 +14
# 'We found no information regarding direct impact on solid-waste facilities as a result of the ﬂood event. However, there is a large pressure on the solid-waste sector to clean the affected areas; 1 month after the event, we observed dozens of large temporary waste ﬁlls and frequent incidences of oil pollution in Rhineland-Palatinate during a ﬁeld visit. In the Ahrweiler district alone, the ﬂood caused as much solid waste as normally would be collected over 30 years. In Belgium, the amount of solid waste is estimated around 160 000 t, stored at several places, such as the abandoned highway track A601. This highway has been used for approximately 9 months as a temporary storage for debris (Couplez, 2022). In the Netherlands, there have been primarily problems with waste deposits along the river banks, which is mostly the solid waste transported by the river from further upstream. Thousands of tonnes of tree debris (logs and\nNat. Hazards Earth Syst. Sci., 22, 3831–3838, 2022\nE. E. Koks et al.: Flood impacts to infrastructure'
#
#
# 'of running water and electricity (Ärzte Zeitung, 2021). After 1.5 months, medical care was guaranteed again in the most affected regions in Rhineland-Palatinate (Hochwasser Ahr, 2021c). In the state of North Rhine-Westphalia, approximately 68 hospitals have been affected, of which several have been affected severely and will take at least 1.5 years to be rebuilt (Fig. 2). Direct damages are estimated to be at least EUR 100 million to repair all medical facilities (Korzilius, 2021). In the town of Eschweiler (Germany), for example, the basement of the hospital was ﬂooded, as well as the outbuildings and the entire outdoor area. The power supply collapsed, the entire building technology was destroyed and some 300 patients had to be evacuated by helicopter. Property damage is expected to be around EUR 50 million. Within 3.5 weeks, the hospital was partly operational, and within 3 months, all hospital operations continued normally (SAH Eschweiler, 2021). The Mutterhaus Ehrang hospital in Trier (Germany) is now permanently closed as the hospital is too severely damaged to rebuild. Furthermore, in the region of Rhineland-Palatinate (Germany), 19'

# %%
doc[14].page_content

# %%
df_ci_geo[df_ci_geo["chunk_id"].isin([13, 14])]

# %%
df_responses[df_responses["chunk_id"].isin([13, 14])]

# %%
print(
    f"CI_TYPE \n LLM responses:\n {df_responses.infrastructure_type.unique()}, \n\n NER pairs:\n {df_ci_geo.ci_entity.unique()}"
)

# %%
print(
    f"LOCATION:\n LLm responses:\n {df_responses.location.unique()}, \n\n NER pairs:\n {df_ci_geo.geo_entity.unique()}"
)

# %% [markdown]
# ## Test alternative approaches for entity linking / relation extraction

# %%
import torch
import gc

print(torch.cuda.memory_summary(device=None, abbreviated=False))
# # empyty CUDA cache
gc.collect()

torch.cuda.empty_cache()
torch.no_grad()
# print(torch.cuda.memory_summary(device=None, abbreviated=False))
